# %%
import analyze_log 

df = analyze_log.highest_proc

print(df)
# Out:
#                      Time    Pid       Date  \
# 1999  1734480887687000000  25746 2017-05-16
# 1998  1734480887663000000   2931 2017-05-16
# 1997  1734480887652000000  25799 2017-05-16
# 1996  1734480887447000000   2931 2017-05-16
# 1995  1734480887410000000  25746 2017-05-16
# ...                   ...    ...        ...
# 4     1734480003091000000  25746 2017-05-16
# 3     1734480001813000000  25746 2017-05-16
# 2     1734480001551000000  25746 2017-05-16
# 1     1734480000272000000  25746 2017-05-16
# 0     1734480000008000000  25746 2017-05-16
#
#                                    Logrecord
# 1999      nova-api.log.1.2017-05-16_13:53:08
# 1998  nova-compute.log.1.2017-05-16_13:55:31
# 1997      nova-api.log.1.2017-05-16_13:53:08
# 1996  nova-compute.log.1.2017-05-16_13:55:31
# 1995      nova-api.log.1.2017-05-16_13:53:08
# ...                                      ...
# 4         nova-api.log.1.2017-05-16_13:53:08
# 3         nova-api.log.1.2017-05-16_13:53:08
# ...

# %%
import cc_data_analysis
import matplotlib.pyplot as plt
import seaborn as sns

df = cc_data_analysis.top_30_highest_calls
plt.figure(figsize= (5,2))
chart = sns.boxenplot(df['Incoming Calls'])

plt.show()

# %%
import cc_data_analysis
import matplotlib.pyplot as plt
import seaborn as sns



df = cc_data_analysis.top_30_highest_calls

chart = sns.displot(df['Incoming Calls'], kind = 'kde', height= 5 , aspect= 2)
plt.show()

# %%
import cc_data_analysis
df = cc_data_analysis.top_30_highest_calls
print(df)
# Out:
#            Date    Column1  Index  Incoming Calls  Answered Calls  \
# 838  2019-07-18   Thursday    839            1575             871
# 839  2019-07-19     Friday    840            1349             775
# 849  2019-07-29     Monday    850            1242             909
# 883  2019-09-01     Sunday    884            1196             718
# 912  2019-09-30     Monday    913            1141             610
# 848  2019-07-28     Sunday    849            1100             823
# 842  2019-07-22     Monday    843            1066             453
# 836  2019-07-16    Tuesday    837            1057             602
# 840  2019-07-20   Saturday    841             999             454
# 841  2019-07-21     Sunday    842             968             547
# 951  2019-11-08     Friday    952             954             644
# 911  2019-09-29     Sunday    912             905             631
# 913  2019-10-01    Tuesday    914             863             511
# ...

# %%
import cc_data_analysis
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Top 30 Dates with Highest Calls:
#            Date  Incoming Calls
# 838  2019-07-18            1575
# 839  2019-07-19            1349
# 849  2019-07-29            1242
# 883  2019-09-01            1196
# 912  2019-09-30            1141
# 848  2019-07-28            1100
# 842  2019-07-22            1066
# 836  2019-07-16            1057
# 840  2019-07-20             999
# 841  2019-07-21             968
# 951  2019-11-08             954
# 911  2019-09-29             905
# 913  2019-10-01             863
# 846  2019-07-26             847
# 845  2019-07-25             842
# 240  2017-11-27             822
# 847  2019-07-27             800
# 843  2019-07-23             788
# 799  2019-06-09             732
# 850  2019-07-30             732
# 882  2019-08-31             729
# 798  2019-06-08             724
# 351  2018-03-18             721
# 835  2019-07-15             712
# 881  2019-08-30             648
# 1193 2020-07-07             627
# 910  2019-09-28             627
# ...
